# %%
# !pip install -U ultralytics wandb
# Out:
# Requirement already satisfied: ultralytics in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (8.4.34)
# Collecting ultralytics
#   Downloading ultralytics-8.4.38-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: wandb in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (0.25.1)
# Collecting wandb
#   Downloading wandb-0.26.0-py3-none-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: polars>=0.20.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.39.3)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: click>=8.0.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from wandb) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from wandb) (3.1.46)
# Requirement already satisfied: packaging in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from wandb) (26.0)
# Requirement already satisfied: platformdirs in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from wandb) (6.33.3)
# Requirement already satisfied: pydantic<3 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from wandb) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from wandb) (2.57.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from wandb) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: colorama in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from click>=8.0.1->wandb) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.39.3 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from polars>=0.20.0->ultralytics) (1.39.3)
# Requirement already satisfied: six>=1.5 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: filelock in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: networkx in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\richard\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.38-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 10.3 MB/s  0:00:00
# Downloading wandb-0.26.0-py3-none-win_amd64.whl (24.9 MB)
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    --- ------------------------------------ 2.4/24.9 MB 11.2 MB/s eta 0:00:03
#    ------- -------------------------------- 4.7/24.9 MB 11.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.1/24.9 MB 11.5 MB/s eta 0:00:02
#    --------------- ------------------------ 9.7/24.9 MB 11.6 MB/s eta 0:00:02
#    ------------------- -------------------- 12.1/24.9 MB 11.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.7/24.9 MB 11.8 MB/s eta 0:00:01
#    --------------------------- ------------ 17.0/24.9 MB 11.8 MB/s eta 0:00:01
#    ------------------------------- -------- 19.4/24.9 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.8/24.9 MB 11.8 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/24.9 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 24.9/24.9 MB 11.6 MB/s  0:00:02
# Installing collected packages: wandb, ultralytics
#
#   Attempting uninstall: wandb
#
#     Found existing installation: wandb 0.25.1
#
#    ---------------------------------------- 0/2 [wandb]
#     Uninstalling wandb-0.25.1:
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#       Successfully uninstalled wandb-0.25.1
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#    ---------------------------------------- 0/2 [wandb]
#   Attempting uninstall: ultralytics
#    ---------------------------------------- 0/2 [wandb]
#     Found existing installation: ultralytics 8.4.34
#    ---------------------------------------- 0/2 [wandb]
#    -------------------- ------------------- 1/2 [ultralytics]
#     Uninstalling ultralytics-8.4.34:
#    -------------------- ------------------- 1/2 [ultralytics]
#       Successfully uninstalled ultralytics-8.4.34
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    -------------------- ------------------- 1/2 [ultralytics]
#    ---------------------------------------- 2/2 [ultralytics]
#
# Successfully installed ultralytics-8.4.38 wandb-0.26.0

# %%
def print_excel_row(model_name, val, test):
    print(f"{model_name}\t"
          f"{val.box.mr:.4f}\t"
          f"{val.box.mp:.4f}\t"
          f"{val.box.map50:.4f}\t"
          f"{val.box.map:.4f}\t"
          f"{test.box.mr:.4f}\t"
          f"{test.box.mp:.4f}\t"
          f"{test.box.map50:.4f}\t"
          f"{test.box.map:.4f}")

# %%
yaml_content = """
path: dataset

train: yolo_dataset/images/train
val: yolo_dataset/images/val
test: yolo_dataset/images/test

nc: 3
names: ['WBC', 'RBC', 'Platelets']
"""

with open("wbc.yaml", "w") as f:
    f.write(yaml_content)

# %% [markdown]
# LR Tuning

# %%
from ultralytics import YOLO

models = {
    "LR_0.001": "runs/detect/11s_baseline/weights/best.pt",
    "LR_0.0005": "runs/detect/11s_lr_0.0005/weights/best.pt",
    "LR_0.0001": "runs/detect/11s_lr_0.0001/weights/best.pt",
    "LR_0.00001": "runs/detect/11s_lr_0.00001/weights/best.pt"
}

results = []

for name, path in models.items():
    model = YOLO(path)

    metrics = model.val(data="wbc.yaml", split="val", verbose=False)

    results.append({
        "Model": name,
        "Precision": metrics.box.mp,
        "Recall": metrics.box.mr,
        "mAP50": metrics.box.map50,
        "mAP50-95": metrics.box.map
    })

print("Model\tPrecision\tRecall\tmAP50\tmAP50-95")
for r in results:
    print(f"{r['Model']}\t{r['Precision']:.4f}\t{r['Recall']:.4f}\t{r['mAP50']:.4f}\t{r['mAP50-95']:.4f}")
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 443.8123.7 MB/s, size: 20.4 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.3s0.6ss
#                    all         72       1006      0.882      0.889      0.929      0.616
# Speed: 2.1ms preprocess, 13.2ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val11
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 385.487.6 MB/s, size: 20.8 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1it/s 4.5s0.5s0s
#                    all         72       1006      0.892      0.858      0.923       0.62
# Speed: 2.1ms preprocess, 12.8ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val12
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 384.591.2 MB/s, size: 20.3 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.2s0.5ss
#                    all         72       1006      0.857      0.929      0.922      0.631
# Speed: 2.0ms preprocess, 12.9ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val13
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 319.494.0 MB/s, size: 19.6 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.3s0.6ss
#                    all         72       1006      0.863      0.907      0.922      0.634
# Speed: 2.1ms preprocess, 12.9ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val14
# Model	Precision	Recall	mAP50	mAP50-95
# LR_0.001	0.8820	0.8885	0.9286	0.6162
# LR_0.0005	0.8921	0.8575	0.9233	0.6201
# LR_0.0001	0.8566	0.9285	0.9222	0.6311
# LR_0.00001	0.8630	0.9067	0.9221	0.6344

# %% [markdown]
# Base LR with Augmentation

# %%
from ultralytics import YOLO

models = {
    "Base LR - No Augment"  : "runs/detect/11s_baseline/weights/best.pt",
    "Base LR - Recommended" : "runs/detect/11s_baseline_augment/weights/best.pt",
    "Base LR - Strong"      : "runs/detect/11s_baseline_aug_strong/weights/best.pt",
}

results = []

for name, path in models.items():
    model = YOLO(path)

    metrics = model.val(data="wbc.yaml", split="val", verbose=False)

    results.append({
        "Model": name,
        "Precision": metrics.box.mp,
        "Recall": metrics.box.mr,
        "mAP50": metrics.box.map50,
        "mAP50-95": metrics.box.map
    })

print("Model\tPrecision\tRecall\tmAP50\tmAP50-95")
for r in results:
    print(f"{r['Model']}\t{r['Precision']:.4f}\t{r['Recall']:.4f}\t{r['mAP50']:.4f}\t{r['mAP50-95']:.4f}")
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 315.982.8 MB/s, size: 20.2 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.3s0.5s8s
#                    all         72       1006      0.882      0.889      0.929      0.616
# Speed: 2.3ms preprocess, 11.6ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 268.358.8 MB/s, size: 20.4 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.1s0.5ss
#                    all         72       1006      0.892      0.881      0.931      0.629
# Speed: 2.1ms preprocess, 13.4ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val2
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 208.5109.7 MB/s, size: 20.8 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.2s0.5ss
#                    all         72       1006      0.877      0.914      0.927      0.639
# Speed: 1.9ms preprocess, 12.2ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val3
# Model	Precision	Recall	mAP50	mAP50-95
# Base LR - No Augment	0.8820	0.8885	0.9286	0.6162
# Base LR - Recommended	0.8916	0.8809	0.9315	0.6292
# Base LR - Strong	0.8774	0.9140	0.9274	0.6394

# %% [markdown]
# Best LR with Augment

# %%
from ultralytics import YOLO

models = {
    "Best LR - No Augment"  : "runs/detect/11s_lr_0.00001/weights/best.pt",
    "Best LR - Recommended" : "runs/detect/11s_lr_augment/weights/best.pt",
    "Best LR - Strong"      : "runs/detect/11s_lr_strong_augment/weights/best.pt",
}

results = []

for name, path in models.items():
    model = YOLO(path)

    metrics = model.val(data="wbc.yaml", split="val", verbose=False)

    results.append({
        "Model": name,
        "Precision": metrics.box.mp,
        "Recall": metrics.box.mr,
        "mAP50": metrics.box.map50,
        "mAP50-95": metrics.box.map
    })

print("Model\tPrecision\tRecall\tmAP50\tmAP50-95")
for r in results:
    print(f"{r['Model']}\t{r['Precision']:.4f}\t{r['Recall']:.4f}\t{r['mAP50']:.4f}\t{r['mAP50-95']:.4f}")
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 336.9151.0 MB/s, size: 19.6 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.2s0.5ss
#                    all         72       1006      0.863      0.907      0.922      0.634
# Speed: 2.1ms preprocess, 11.5ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val4
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 301.0100.5 MB/s, size: 20.3 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.3s0.6ss
#                    all         72       1006      0.885      0.913      0.933      0.632
# Speed: 2.0ms preprocess, 12.2ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val5
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 282.3100.8 MB/s, size: 19.9 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.2s0.6ss
#                    all         72       1006      0.851      0.917      0.913      0.618
# Speed: 2.1ms preprocess, 12.4ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val6
# Model	Precision	Recall	mAP50	mAP50-95
# Best LR - No Augment	0.8630	0.9067	0.9221	0.6344
# Best LR - Recommended	0.8850	0.9130	0.9329	0.6318
# Best LR - Strong	0.8513	0.9167	0.9129	0.6177

# %% [markdown]
# Auto Tuning vs Manual Tuning (Fair harus ke Test)

# %%
from ultralytics import YOLO

models = {
    "Best LR - Recommended" : "runs/detect/11s_lr_augment/weights/best.pt",
    "Auto Tuning"           : "runs/detect/11s_auto_tune/weights/best.pt",
}

results = []

for name, path in models.items():
    model = YOLO(path)

    metrics = model.val(data="wbc.yaml", split="test", verbose=False)

    results.append({
        "Model": name,
        "Precision": metrics.box.mp,
        "Recall": metrics.box.mr,
        "mAP50": metrics.box.map50,
        "mAP50-95": metrics.box.map
    })

print("Model\tPrecision\tRecall\tmAP50\tmAP50-95")
for r in results:
    print(f"{r['Model']}\t{r['Precision']:.4f}\t{r['Recall']:.4f}\t{r['mAP50']:.4f}\t{r['mAP50-95']:.4f}")
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 458.7134.8 MB/s, size: 20.2 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\test.cache... 36 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 36/36  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.6s1.2ss
#                    all         36        485      0.868      0.898      0.939       0.67
# Speed: 2.4ms preprocess, 12.2ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val12
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 411.3113.3 MB/s, size: 21.0 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\test.cache... 36 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 36/36  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.6s1.3ss
#                    all         36        485      0.842      0.889      0.926      0.636
# Speed: 2.4ms preprocess, 14.2ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val13
# Model	Precision	Recall	mAP50	mAP50-95
# Best LR - Recommended	0.8685	0.8981	0.9388	0.6701
# Auto Tuning	0.8424	0.8890	0.9258	0.6357

# %% [markdown]
# YOLOv8s vs YOLOv11s (Tuned with same Parameter) - Test Set

# %%
from ultralytics import YOLO

models = {
    "YOLOv8s Best LR - Recommended" : "runs/detect/v8s_tuned_comparison/weights/best.pt",
    "YOLO11s Best LR - Recommended" : "runs/detect/11s_lr_augment/weights/best.pt",
}

results = []

for name, path in models.items():
    model = YOLO(path)

    metrics = model.val(data="wbc.yaml", split="test", verbose=False)

    results.append({
        "Model": name,
        "Precision": metrics.box.mp,
        "Recall": metrics.box.mr,
        "mAP50": metrics.box.map50,
        "mAP50-95": metrics.box.map
    })

print("Model\tPrecision\tRecall\tmAP50\tmAP50-95")
for r in results:
    print(f"{r['Model']}\t{r['Precision']:.4f}\t{r['Recall']:.4f}\t{r['mAP50']:.4f}\t{r['mAP50-95']:.4f}")
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.10.1 ms, read: 171.681.9 MB/s, size: 21.1 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\test.cache... 36 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 36/36  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.4s1.9s0s
#                    all         36        485      0.801      0.919      0.909      0.637
# Speed: 3.3ms preprocess, 19.7ms inference, 0.0ms loss, 9.8ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val8
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 174.640.0 MB/s, size: 20.9 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\test.cache... 36 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 36/36  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.5s1.8s6s
#                    all         36        485      0.868      0.898      0.939       0.67
# Speed: 3.6ms preprocess, 18.1ms inference, 0.0ms loss, 7.5ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val9
# Model	Precision	Recall	mAP50	mAP50-95
# YOLOv8s Best LR - Recommended	0.8009	0.9188	0.9092	0.6366
# YOLO11s Best LR - Recommended	0.8685	0.8981	0.9388	0.6701

# %%
import time
import os

model_v8 = YOLO("runs/detect/v8s_tuned_comparison/weights/best.pt")

start = time.time()
results = model_v8.predict("dataset/yolo_dataset/images/test", stream=True)

for r in results:
    pass
end = time.time()

fps = len(os.listdir("dataset/yolo_dataset/images/test")) / (end - start)
print("FPS:", fps)
# Out:
# image 1/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00003.jpg: 480x640 1 WBC, 21 RBCs, 2 Plateletss, 28.6ms
# image 2/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00005.jpg: 480x640 1 WBC, 19 RBCs, 3 Plateletss, 9.4ms
# image 3/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00007.jpg: 480x640 1 WBC, 21 RBCs, 1 Platelets, 10.7ms
# image 4/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00009.jpg: 480x640 1 WBC, 23 RBCs, 1 Platelets, 9.8ms
# image 5/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00022.jpg: 480x640 1 WBC, 24 RBCs, 3 Plateletss, 10.0ms
# image 6/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00059.jpg: 480x640 1 WBC, 19 RBCs, 1 Platelets, 9.7ms
# image 7/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00071.jpg: 480x640 1 WBC, 18 RBCs, 2 Plateletss, 9.7ms
# image 8/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00077.jpg: 480x640 1 WBC, 16 RBCs, 2 Plateletss, 9.3ms
# image 9/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00090.jpg: 480x640 1 WBC, 17 RBCs, 3 Plateletss, 10.0ms
# image 10/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00103.jpg: 480x640 2 WBCs, 20 RBCs, 1 Platelets, 9.6ms
# image 11/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00125.jpg: 480x640 1 WBC, 21 RBCs, 3 Plateletss, 10.3ms
# image 12/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00144.jpg: 480x640 1 WBC, 14 RBCs, 9.3ms
# image 13/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00147.jpg: 480x640 1 WBC, 16 RBCs, 1 Platelets, 9.8ms
# image 14/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00156.jpg: 480x640 1 WBC, 20 RBCs, 6 Plateletss, 10.2ms
# image 15/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00161.jpg: 480x640 1 WBC, 25 RBCs, 10.2ms
# image 16/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00163.jpg: 480x640 1 WBC, 27 RBCs, 1 Platelets, 10.0ms
# image 17/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00171.jpg: 480x640 2 WBCs, 20 RBCs, 9.5ms
# image 18/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00172.jpg: 480x640 1 WBC, 26 RBCs, 9.9ms
# image 19/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00177.jpg: 480x640 1 WBC, 24 RBCs, 2 Plateletss, 9.3ms
# image 20/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00183.jpg: 480x640 1 WBC, 24 RBCs, 2 Plateletss, 9.2ms
# image 21/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00225.jpg: 480x640 1 WBC, 24 RBCs, 1 Platelets, 9.2ms
# image 22/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00230.jpg: 480x640 1 WBC, 28 RBCs, 1 Platelets, 9.6ms
# image 23/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00242.jpg: 480x640 2 WBCs, 29 RBCs, 1 Platelets, 9.3ms
# image 24/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00243.jpg: 480x640 1 WBC, 25 RBCs, 8.8ms
# image 25/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00256.jpg: 480x640 1 WBC, 25 RBCs, 8.8ms
# image 26/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00261.jpg: 480x640 1 WBC, 21 RBCs, 1 Platelets, 9.6ms
# image 27/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00264.jpg: 480x640 1 WBC, 23 RBCs, 1 Platelets, 9.2ms
# image 28/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00301.jpg: 480x640 1 WBC, 25 RBCs, 2 Plateletss, 9.6ms
# image 29/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00319.jpg: 480x640 1 WBC, 23 RBCs, 2 Plateletss, 9.3ms
# image 30/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00334.jpg: 480x640 1 WBC, 22 RBCs, 10.4ms
# image 31/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00346.jpg: 480x640 1 WBC, 24 RBCs, 9.1ms
# image 32/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00359.jpg: 480x640 1 WBC, 23 RBCs, 1 Platelets, 9.7ms
# image 33/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00361.jpg: 480x640 1 WBC, 25 RBCs, 1 Platelets, 9.3ms
# image 34/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00368.jpg: 480x640 1 WBC, 33 RBCs, 9.3ms
# image 35/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00404.jpg: 480x640 1 WBC, 25 RBCs, 1 Platelets, 9.7ms
# image 36/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00405.jpg: 480x640 1 WBC, 22 RBCs, 1 Platelets, 9.5ms
# Speed: 1.5ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# FPS: 43.932409325271614

# %%
import time
import os

model_v11 = YOLO("runs/detect/11s_lr_augment/weights/best.pt")

start = time.time()
results = model_v11.predict("dataset/yolo_dataset/images/test", stream=True)

for r in results:
    pass
end = time.time()

fps = len(os.listdir("dataset/yolo_dataset/images/test")) / (end - start)
print("FPS:", fps)
# Out:
# image 1/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00003.jpg: 480x640 1 WBC, 23 RBCs, 1 Platelets, 14.0ms
# image 2/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00005.jpg: 480x640 1 WBC, 22 RBCs, 3 Plateletss, 11.2ms
# image 3/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00007.jpg: 480x640 1 WBC, 15 RBCs, 10.5ms
# image 4/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00009.jpg: 480x640 1 WBC, 26 RBCs, 1 Platelets, 9.5ms
# image 5/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00022.jpg: 480x640 1 WBC, 21 RBCs, 3 Plateletss, 10.0ms
# image 6/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00059.jpg: 480x640 1 WBC, 17 RBCs, 1 Platelets, 9.6ms
# image 7/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00071.jpg: 480x640 1 WBC, 17 RBCs, 9.2ms
# image 8/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00077.jpg: 480x640 1 WBC, 12 RBCs, 1 Platelets, 16.4ms
# image 9/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00090.jpg: 480x640 1 WBC, 21 RBCs, 2 Plateletss, 9.9ms
# image 10/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00103.jpg: 480x640 2 WBCs, 20 RBCs, 9.5ms
# image 11/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00125.jpg: 480x640 1 WBC, 20 RBCs, 1 Platelets, 10.1ms
# image 12/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00144.jpg: 480x640 1 WBC, 12 RBCs, 9.6ms
# image 13/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00147.jpg: 480x640 1 WBC, 9 RBCs, 1 Platelets, 9.1ms
# image 14/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00156.jpg: 480x640 1 WBC, 19 RBCs, 7 Plateletss, 8.9ms
# image 15/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00161.jpg: 480x640 1 WBC, 22 RBCs, 1 Platelets, 9.2ms
# image 16/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00163.jpg: 480x640 1 WBC, 21 RBCs, 1 Platelets, 8.9ms
# image 17/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00171.jpg: 480x640 2 WBCs, 20 RBCs, 8.5ms
# image 18/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00172.jpg: 480x640 1 WBC, 22 RBCs, 10.0ms
# image 19/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00177.jpg: 480x640 1 WBC, 19 RBCs, 2 Plateletss, 9.5ms
# image 20/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00183.jpg: 480x640 1 WBC, 20 RBCs, 2 Plateletss, 9.8ms
# image 21/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00225.jpg: 480x640 1 WBC, 19 RBCs, 1 Platelets, 13.4ms
# image 22/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00230.jpg: 480x640 1 WBC, 20 RBCs, 14.2ms
# image 23/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00242.jpg: 480x640 2 WBCs, 21 RBCs, 1 Platelets, 12.2ms
# image 24/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00243.jpg: 480x640 1 WBC, 19 RBCs, 11.2ms
# image 25/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00256.jpg: 480x640 1 WBC, 21 RBCs, 9.2ms
# image 26/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00261.jpg: 480x640 1 WBC, 18 RBCs, 1 Platelets, 8.8ms
# image 27/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00264.jpg: 480x640 1 WBC, 21 RBCs, 1 Platelets, 9.6ms
# image 28/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00301.jpg: 480x640 1 WBC, 24 RBCs, 2 Plateletss, 9.3ms
# image 29/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00319.jpg: 480x640 1 WBC, 19 RBCs, 2 Plateletss, 8.8ms
# image 30/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00334.jpg: 480x640 1 WBC, 20 RBCs, 10.6ms
# image 31/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00346.jpg: 480x640 1 WBC, 23 RBCs, 9.1ms
# image 32/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00359.jpg: 480x640 1 WBC, 22 RBCs, 1 Platelets, 13.0ms
# image 33/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00361.jpg: 480x640 1 WBC, 21 RBCs, 14.0ms
# image 34/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00368.jpg: 480x640 1 WBC, 29 RBCs, 9.8ms
# image 35/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00404.jpg: 480x640 1 WBC, 17 RBCs, 1 Platelets, 8.9ms
# image 36/36 d:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\images\test\BloodImage_00405.jpg: 480x640 1 WBC, 19 RBCs, 1 Platelets, 8.7ms
# Speed: 1.2ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# FPS: 51.30908609001478

# %% [markdown]
# Per Class

# %% [markdown]
# Best LR - No Augment (Base)

# %%
model =  YOLO("runs/detect/11s_lr_0.00001//weights/best.pt")

val_metrics = model.val(data="wbc.yaml", split="val")
test_metrics = model.val(data="wbc.yaml", split="test")

print("Model\tVal Recall\tVal Precision\tVal mAP50\tVal mAP50-95\tTest Recall\tTest Precision\tTest mAP50\tTest mAP50-95")
print_excel_row("YOLO11s_Base", val_metrics, test_metrics)
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.10.1 ms, read: 284.7179.3 MB/s, size: 19.5 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.3s0.6ss
#                    all         72       1006      0.863      0.907      0.922      0.634
#                    WBC         69         71      0.952          1      0.992      0.826
#                    RBC         70        844      0.806      0.849      0.883      0.619
#              Platelets         47         91      0.832      0.871      0.892      0.458
# Speed: 2.3ms preprocess, 11.9ms inference, 0.0ms loss, 5.3ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val5
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# val: Fast image access  (ping: 0.00.0 ms, read: 303.1107.7 MB/s, size: 20.3 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\test.cache... 36 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 36/36  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.3s/it 4.0s1.4s4s
#                    all         36        485      0.803       0.93      0.907      0.643
#                    WBC         35         35      0.909          1      0.994      0.822
#                    RBC         35        414      0.735      0.882      0.892      0.653
#              Platelets         19         36      0.766      0.909      0.836      0.453
# Speed: 2.2ms preprocess, 12.2ms inference, 0.0ms loss, 9.7ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val6
# Model	Val Recall	Val Precision	Val mAP50	Val mAP50-95	Test Recall	Test Precision	Test mAP50	Test mAP50-95
# YOLO11s_Base	0.9067	0.8630	0.9221	0.6344	0.9304	0.8033	0.9071	0.6427

# %% [markdown]
# Best LR - Recommended Augment

# %%
model =  YOLO("runs/detect/11s_lr_augment/weights/best.pt")

val_metrics = model.val(data="wbc.yaml", split="val")
test_metrics = model.val(data="wbc.yaml", split="test")

print("Model\tVal Recall\tVal Precision\tVal mAP50\tVal mAP50-95\tTest Recall\tTest Precision\tTest mAP50\tTest mAP50-95")
print_excel_row("YOLO11s_Best_Recommended", val_metrics, test_metrics)
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 305.397.1 MB/s, size: 19.6 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1it/s 4.7s0.6s3s
#                    all         72       1006      0.885      0.913      0.933      0.632
#                    WBC         69         71      0.945          1       0.98      0.812
#                    RBC         70        844      0.826      0.827      0.887      0.623
#              Platelets         47         91      0.885      0.912      0.932       0.46
# Speed: 2.6ms preprocess, 13.4ms inference, 0.0ms loss, 4.6ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val7
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# val: Fast image access  (ping: 0.00.0 ms, read: 296.589.3 MB/s, size: 19.8 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\test.cache... 36 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 36/36  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.4s/it 4.2s1.4s4s
#                    all         36        485      0.868      0.898      0.939       0.67
#                    WBC         35         35      0.907          1      0.987      0.808
#                    RBC         35        414      0.835      0.833      0.906      0.668
#              Platelets         19         36      0.864      0.861      0.923      0.534
# Speed: 2.3ms preprocess, 12.4ms inference, 0.0ms loss, 7.6ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val8
# Model	Val Recall	Val Precision	Val mAP50	Val mAP50-95	Test Recall	Test Precision	Test mAP50	Test mAP50-95
# YOLO11s_Best_Recommended	0.9130	0.8850	0.9329	0.6318	0.8981	0.8685	0.9388	0.6701

# %% [markdown]
# Best LR - Strong Augment

# %%
model =  YOLO("runs/detect/11s_lr_strong_augment//weights/best.pt")

val_metrics = model.val(data="wbc.yaml", split="val")
test_metrics = model.val(data="wbc.yaml", split="test")

print("Model\tVal Recall\tVal Precision\tVal mAP50\tVal mAP50-95\tTest Recall\tTest Precision\tTest mAP50\tTest mAP50-95")
print_excel_row("YOLO11s_Best_Strong", val_metrics, test_metrics)
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 406.0119.6 MB/s, size: 20.3 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.2s0.5ss
#                    all         72       1006      0.851      0.917      0.913      0.618
#                    WBC         69         71      0.931          1      0.971      0.798
#                    RBC         70        844      0.772      0.875      0.882      0.617
#              Platelets         47         91      0.851      0.875      0.886      0.438
# Speed: 1.9ms preprocess, 12.5ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val9
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# val: Fast image access  (ping: 0.00.0 ms, read: 361.280.9 MB/s, size: 20.4 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\test.cache... 36 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 36/36  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.5s1.3ss
#                    all         36        485      0.867      0.885      0.925      0.656
#                    WBC         35         35      0.927          1      0.988       0.81
#                    RBC         35        414      0.793       0.83      0.895      0.653
#              Platelets         19         36      0.881      0.826      0.892      0.503
# Speed: 2.4ms preprocess, 12.3ms inference, 0.0ms loss, 5.6ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val10
# Model	Val Recall	Val Precision	Val mAP50	Val mAP50-95	Test Recall	Test Precision	Test mAP50	Test mAP50-95
# YOLO11s_Best_Strong	0.9167	0.8513	0.9129	0.6177	0.8855	0.8668	0.9251	0.6556

# %% [markdown]
# Visualize

# %% [markdown]
# Load Model

# %%
from ultralytics import YOLO

best_model = YOLO("runs/detect/11s_lr_augment/weights/best.pt")

# %%
val_metrics = best_model.val(data="wbc.yaml", split="val")
test_metrics = best_model.val(data="wbc.yaml", split="test")

print("Model\tVal Recall\tVal Precision\tVal mAP50\tVal mAP50-95\tTest Recall\tTest Precision\tTest mAP50\tTest mAP50-95")
print_excel_row("Best Model", val_metrics, test_metrics)
# Out:
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 357.1118.9 MB/s, size: 19.4 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\val.cache... 72 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 72/72  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.4s/it 7.2s1.0s8
#                    all         72       1006      0.885      0.913      0.933      0.632
#                    WBC         69         71      0.945          1       0.98      0.812
#                    RBC         70        844      0.826      0.827      0.887      0.623
#              Platelets         47         91      0.885      0.912      0.932       0.46
# Speed: 4.0ms preprocess, 16.4ms inference, 0.0ms loss, 5.7ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val3
# Ultralytics 8.4.38  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# val: Fast image access  (ping: 0.00.0 ms, read: 210.787.9 MB/s, size: 20.8 KB)
# val: Scanning D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\dataset\yolo_dataset\labels\test.cache... 36 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 36/36  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.7s/it 8.1s4.0s8s
#                    all         36        485      0.868      0.898      0.939       0.67
#                    WBC         35         35      0.907          1      0.987      0.808
#                    RBC         35        414      0.835      0.833      0.906      0.668
#              Platelets         19         36      0.864      0.861      0.923      0.534
# Speed: 7.5ms preprocess, 24.8ms inference, 0.0ms loss, 11.2ms postprocess per image
# Results saved to D:\Backup Data\BINUS\S2\Semester 2 Periode 1\Deep Learning\AoL 1\Experiment\Final\runs\detect\val4
# Model	Val Recall	Val Precision	Val mAP50	Val mAP50-95	Test Recall	Test Precision	Test mAP50	Test mAP50-95
# Best Model	0.9130	0.8850	0.9329	0.6318	0.8981	0.8685	0.9388	0.6701

# %%
import os, cv2
import matplotlib.pyplot as plt

class_names = ['WBC', 'RBC', 'Platelets']

def visualize_gt_vs_pred(image_path, model):
    img = cv2.imread(image_path)
    if img is None:
        print("Image failed to load:", image_path)
    h, w, _ = img.shape

    label_path = image_path.replace("images", "labels").replace(".jpg", ".txt")

    if os.path.exists(label_path):
        with open(label_path) as f:
            for line in f:
                cls, x, y, bw, bh = map(float, line.split())

                x1 = int((x - bw/2) * w)
                y1 = int((y - bh/2) * h)
                x2 = int((x + bw/2) * w)
                y2 = int((y + bh/2) * h)

                label = class_names[int(cls)]

                cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 2)
                cv2.putText(
                    img,
                    f"GT: {label}",
                    (x1, y1 - 5),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,
                    (0,255,0),
                    2
                )

    results = model(img)[0]

    boxes = results.boxes.xyxy
    scores = results.boxes.conf
    classes = results.boxes.cls

    for box, score, cls in zip(boxes, scores, classes):
        x1, y1, x2, y2 = map(int, box)
        label = class_names[int(cls)]

        cv2.rectangle(img, (x1, y1), (x2, y2), (0,0,255), 2)
        cv2.putText(
            img,
            f"{label} {score:.2f}",
            (x1, y2 + 15),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (0,0,255),
            2
        )

    plt.figure(figsize=(8,8))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()
    plt.close()

# %%
import os
import random

def process_random_predictions(dataset_path, model, num_samples=5):

    all_files = [f for f in os.listdir(dataset_path) if f.lower().endswith(('.jpg'))]
    
    sample_size = min(num_samples, len(all_files))
    selected_files = random.sample(all_files, sample_size)
    
    for filename in selected_files:
        image_path = os.path.join(dataset_path, filename)
        
        try:
            visualize_gt_vs_pred(image_path, model)
            print(image_path)
        except Exception as e:
            print(f"Error processing {filename}: {e}")

dataset_path = "dataset/yolo_dataset/images/test"
process_random_predictions(dataset_path, best_model)
# Out:
# 0: 480x640 1 WBC, 20 RBCs, 21.4ms
# Speed: 18.1ms preprocess, 21.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# dataset/yolo_dataset/images/test\BloodImage_00009.jpg
#
# 0: 480x640 1 WBC, 21 RBCs, 1 Platelets, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# dataset/yolo_dataset/images/test\BloodImage_00230.jpg
#
# 0: 480x640 1 WBC, 11 RBCs, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# dataset/yolo_dataset/images/test\BloodImage_00007.jpg
#
# 0: 480x640 1 WBC, 16 RBCs, 2 Plateletss, 23.8ms
# Speed: 3.1ms preprocess, 23.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# dataset/yolo_dataset/images/test\BloodImage_00161.jpg
#
# 0: 480x640 3 WBCs, 19 RBCs, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# dataset/yolo_dataset/images/test\BloodImage_00103.jpg

# %%
visualize_gt_vs_pred(
    "dataset/yolo_dataset/images/test\BloodImage_00156.jpg",
    best_model
)
# Out:
# 0: 480x640 2 WBCs, 17 RBCs, 3 Plateletss, 19.0ms
# Speed: 3.7ms preprocess, 19.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# Robustness Trial

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img_path = "dataset/yolo_dataset/images/test/BloodImage_00003.jpg" 
img = cv2.imread(img_path)

def change_brightness(img, factor):
    return cv2.convertScaleAbs(img, alpha=factor, beta=0)

def add_blur(img):
    return cv2.GaussianBlur(img, (5,5), 0)

variants = {
    "Original": img,
    "Bright": change_brightness(img, 1.5),
    "Dark": change_brightness(img, 0.6),
    "Blur": add_blur(img),
}

plt.figure(figsize=(10,10))

for i, (title, var_img) in enumerate(variants.items()):
    results = best_model.predict(var_img, verbose=False)
    plotted = results[0].plot()

    plt.subplot(2, 2, i+1)
    plt.imshow(cv2.cvtColor(plotted, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis("off")

plt.tight_layout()
plt.savefig("robustness_grid.jpg", dpi=300)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt


img_path = "dataset/yolo_dataset/images/test/BloodImage_00005.jpg" 
img = cv2.imread(img_path)

def change_brightness(img, factor):
    return cv2.convertScaleAbs(img, alpha=factor, beta=0)

def add_blur(img):
    return cv2.GaussianBlur(img, (5,5), 0)

variants = {
    "Original": img,
    "Bright": change_brightness(img, 1.5),
    "Dark": change_brightness(img, 0.6),
    "Blur": add_blur(img),
}

plt.figure(figsize=(10,10))

for i, (title, var_img) in enumerate(variants.items()):
    results = best_model.predict(var_img, verbose=False)
    plotted = results[0].plot()

    plt.subplot(2, 2, i+1)
    plt.imshow(cv2.cvtColor(plotted, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis("off")

plt.tight_layout()
plt.savefig("robustness_grid.jpg", dpi=300)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

class_names = ['WBC', 'RBC', 'Platelets']

colors = {
    'WBC': (255, 0, 0),        # Blue
    'RBC': (0, 255, 0),        # Green
    'Platelets': (0, 0, 255)   # Red
}

def visualize_inference(image_path, model, conf_threshold=0.25):
    img = cv2.imread(image_path)

    results = model(img)[0]

    boxes = results.boxes.xyxy
    scores = results.boxes.conf
    classes = results.boxes.cls

    for box, score, cls in zip(boxes, scores, classes):
        if score < conf_threshold:
            continue

        x1, y1, x2, y2 = map(int, box)
        label = class_names[int(cls)]
        color = colors[label]

        # Draw bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)

        # Put label
        cv2.putText(
            img,
            f"{label} {score:.2f}",
            (x1, y1 - 5),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            color,
            2
        )

    # Show image
    plt.figure(figsize=(8, 8))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()

# %%
visualize_inference("test.jpg", best_model)
# Out:
# 0: 608x640 1 WBC, 20 RBCs, 17.6ms
# Speed: 16.2ms preprocess, 17.6ms inference, 6.5ms postprocess per image at shape (1, 3, 608, 640)

# %%
visualize_inference("test2.jpg", best_model)
# Out:
# 0: 512x640 (no detections), 17.5ms
# Speed: 12.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)

# %% [markdown]
# SAHI (Trial)

# %%
from sahi import AutoDetectionModel

detection_model = AutoDetectionModel.from_pretrained(
    model_type="ultralytics",
    model_path="runs/detect/11s_lr_augment/weights/best.pt",
    confidence_threshold=0.25,
    device="cuda"
)

# %%
from sahi.predict import get_sliced_prediction

result = get_sliced_prediction(
    "test2.jpg",
    detection_model,
    slice_height=256,
    slice_width=256,
    overlap_height_ratio=0.2,
    overlap_width_ratio=0.2
)
# Out:
# Performing prediction on 9 slices.

# %%
import cv2
import matplotlib.pyplot as plt

colors = {
    'WBC': (255, 0, 0),
    'RBC': (0, 255, 0),
    'Platelets': (0, 0, 255)
}

img = cv2.imread("test2.jpg")

for obj in result.object_prediction_list:
    bbox = obj.bbox
    x1, y1, x2, y2 = map(int, [bbox.minx, bbox.miny, bbox.maxx, bbox.maxy])
    
    label = obj.category.name
    score = obj.score.value

    color = colors.get(label, (255, 255, 255)) 

    cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)

    cv2.putText(
        img,
        f"{label} {score:.2f}",
        (x1, y1 - 5),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        color,
        2
    )

plt.figure(figsize=(8, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
